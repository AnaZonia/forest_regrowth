# %% [markdown]
# ## Export data as CSV
#
# Imports all data previously generated and exports it as CSV files for analysis.
#
# Allows for the inclusion or exclusion of edge pixels (not surrounded by secondary forest on all sides) into the analysis.
#
# * **Imports:**
#     * Fire from MapBiomas Collection 3
#     * Floodable Forests from MapBiomas Collection 9 (dummy variable)
#     * Topography from ALOS
#
# * **Exports:** CSV dataframes to run the model.
#   * as a sample of 1 pixel per 100km² grid cell to ensure good spatial coverage without running into memory limits:
#     * `grid_10k_amazon_secondary_edge_removed`
#     * `grid_10k_atlantic_secondary_edge_removed`: samples the Atlantic Forest for a comparison of the land use predictive power outside of the Amazon
#
#   * as a sample of 1 pixel per 1km² grid cell for future projections:
#     * `grid_1k_amazon_pastureland`
#
#   * `field_predictors.csv`: The predictors for the locations of the field data, which are then used in `3_analysis/0_field.r` to predict the biomass accumulation in the validation plots.

# %%
import ee
import geemap
from utils import *

initialize()
config = ProjectConfig()
roi = config.roi
data_folder = config.data_folder
last_year = config.last_year

import nbimporter # lets you import notebooks like regular modules
# %run objects.ipynb

include_sd = True # whether or not to include the standard deviation of the biomass values for error propagation
# restricts age pixels to those NOT in edges of ESA CCI pixels (avoids uncertainty in transitions)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## Main Model

# %%
age = (ee.Image("projects/mapbiomas-public/assets/brazil/lulc/collection9/mapbiomas_collection90_secondary_vegetation_age_v1")
    .select("secondary_vegetation_age_2020")
    .rename("age"))

distance_to_border_mask = ee.Image(f"{data_folder}/distance_to_border_mask")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
fire = (ee.Image("projects/mapbiomas-public/assets/brazil/fire/collection3/mapbiomas_fire_collection3_annual_burned_coverage_v1")
    .select([f"burned_coverage_{year}" for year in config.range_1985_2020])
    .byte()
    .rename([str(year) for year in config.range_1985_2020])
    .gt(0)
    .reduce('sum').rename("num_fires")).unmask(0)

floodable_forests = (ee.Image("projects/mapbiomas-public/assets/brazil/lulc/collection9/mapbiomas_collection90_integration_v1")
        .select(f"classification_{last_year}").eq(6)).rename("floodable_forests")

pasture_area = ee.Image(f"{data_folder}/pastureland_area_1km").rename("area")

### ----------------- Surrounding Landscape -----------------

quarters_ecoreg_biomass = ee.Image("projects/forestregrowth/assets/quarters_ecoreg_biomass")
ecoreg = ee.Image("projects/forestregrowth/assets/ecoreg")
distance_to_deep_forest = ee.Image(f"{data_folder}/distance_to_deep_forest").rename("dist")
sur_cover = ee.Image(f"{data_folder}/sur_cover")

mature_biomass_10k = ee.Image(f"{data_folder}/mature_biomass_10k")
nearest_mature = ee.Image(f"{data_folder}/nearest_mature")

### ----------------- Environmental -----------------

categorical = ee.Image(f"{data_folder}/categorical")
topography = ee.Image("CSP/ERGo/1_0/Global/ALOS_landforms").rename("topography") # 90m resolution
soil = ee.Image(f"{data_folder}/soilgrids")
terraclim = ee.Image(f"{data_folder}/terraclim_1958_2019")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ### Unify data to export as CSV

# %%
def reduce_reproject(image, reducer):
    """Reproject image using mean or first, depending on whether the data is continuous or categorical."""
    return image.reduceResolution(
        reducer = reducer
    ).reproject(age.projection())

# Reproject continuous variables using mean
continuous_vars = [
    biomass,
    sur_cover,
    distance_to_deep_forest,
    nearest_mature.rename("nearest_mature"), # double
    soil, # float
    terraclim.select(["mean_soil", "mean_vpd", "mean_temp", "mean_def", 
                      "mean_srad", "mean_pr", "mean_pdsi", "mean_aet"]) # float and int16
]

# Reproject categorical variables using first
categorical_vars = [
    fire, # int64
    ecoreg, # int16
    categorical, # int8
    topography # int8
]

# Create unified dataset by directly combining bands
unified_data = ee.Image.cat([
    floodable_forests,
    *[reduce_reproject(var, ee.Reducer.mean()) for var in continuous_vars],
    *[reduce_reproject(var, ee.Reducer.first()) for var in categorical_vars]
])

unified_data_pasture = ee.Image.cat([
    unified_data,
    pasture_area.rename('pasture_area'),
    ee.Image.pixelLonLat().rename(['lon', 'lat'])
])

unified_data_secondary = ee.Image.cat([
    unified_data,
    age # int8
])
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
if (include_sd == True):
    sd = ee.ImageCollection("projects/sat-io/open-datasets/ESA/ESA_CCI_AGB").filterDate('2020-01-01','2021-01-01').first().select("SD").rename("sd")
    sd_reproj = reduce_reproject(sd, ee.Reducer.first())

    unified_data_secondary = ee.Image.cat([unified_data_secondary, sd])

    grid = ee.FeatureCollection("projects/forestregrowth/assets/grid_10k_amazon_ESACCI_interior")
else:
    grid = ee.FeatureCollection("projects/forestregrowth/assets/grid_10k_amazon_secondary_edge_removed")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ### export_csv
#
# Since processing gets too heavy if we try to extract each point at a time for the entire Amazon at 1km resolution, we do it in chunks using the previously defined grids for sampling at the chosen spatial scale.
#
# `grid_size`: (1 or 10), grid cell size in km to be sampled (imports grids)
# `n_chunks`: how many feature collections to break the grid in for exporting without running into memory limits

# %%
def export_csv(name, image, grid_size, n_chunks = 1, lu_name = None, grid = grid):

    properties_to_export = image.bandNames().getInfo()
    
    total_features = grid.size().getInfo()
    chunk_size = int(total_features * 1/n_chunks)

    if lu_name:
        name = f"{name}_{lu_name}"

    if grid_size == 1:
        grid = ee.FeatureCollection(f"{data_folder}/grid_1k_amazon_{name}") 

    def process_chunk(chunk_index):
        start = chunk_index * chunk_size
        chunk = grid.toList(chunk_size, start)
        selected_pixels = ee.FeatureCollection(chunk)

        unified_fc = image.reduceRegions(selected_pixels, ee.Reducer.first(), 30)

        task = ee.batch.Export.table.toDrive(
            collection = unified_fc,
            description = f"grid_{grid_size}k_{name}_{chunk_index}",
            fileFormat = "CSV",
            selectors = [p for p in properties_to_export if p not in ['system:index', '.geo']]
        )
        task.start()

    for i in range(n_chunks):
        if i*chunk_size < total_features:
            process_chunk(i)

# export_csv("secondary", unified_data_secondary, 10, n_chunks = 30)
# export_csv("pastureland", unified_data_pasture, 1, n_chunks = 60)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# for the revisions: 
# grid = ee.FeatureCollection("projects/forestregrowth/assets/grid_10k_amazon_edge_removed_by_age")

# when is this necessary?
# quarters_ecoreg_biomass
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## Land Use Model

# %%
lu_names = [
    "aggregated_all",
    "non_aggregated_all",
    "non_aggregated_10yr",
    "non_aggregated_5yr"
]

for lu_name in lu_names:
    combined_image = ee.Image.cat([
        unified_data, 
        ee.Image(f"{data_folder}/land_use_{lu_name}")
    ])

# export_csv("secondary", combined_image, 10, n_chunks=30, lu_name = lu_name)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# use the grid from atlantic forest for land use comparison
grid = ee.FeatureCollection(f"{data_folder}/grid_10k_atlantic_secondary_edge_removed")

# export_csv("secondary_atlantic", combined_image, 10, n_chunks=30, lu_name = lu_name)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## Field data and predictors
#
# Imports `field.shp`, produced in `2_modelling/groa_field_data.r` and uploaded to GEE as a Feature Collection.
#
# Exports the predictors for the locations of the field data (`field_predictors.csv`), which are then used in `3_analysis/0_field.r` to predict the biomass accumulation in the validation plots.

# %%
field = ee.FeatureCollection(f"{data_folder}/field")

unified_fc = unified_data.reduceRegions(field, ee.Reducer.first(), 30)

properties_to_export = unified_data.bandNames().getInfo()
properties_to_export = properties_to_export + ["age", "site_id", "plot_id", "field_biom"]

task = ee.batch.Export.table.toDrive(
    collection = unified_fc,
    description = 'field_predictors',
    fileFormat = "CSV",
    selectors = [p for p in properties_to_export if p not in ['system:index', '.geo']]
)
# task.start()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## Future projections - Bezerra map
#
# Use the projections from [Bezerra et al. 2022](https://doi.org/10.1371/journal.pone.0256052) to predict the future biomass accumulated by secondary forests.

# %%
biomes = ee.Image(f"{config.data_folder}/categorical").select("biome")
biomes = biomes.eq(1).selfMask()

scenarios = ["SSP1_RCP19", "SSP2_RCP45", "SSP3_RCP70"]

scenarios_growth = ee.Image()

for scenario in scenarios:
    scenario_2015 = ee.Image(f"projects/forestregrowth/assets/projections/forest_2015_{scenario}")
    scenario_2050 = ee.Image(f"projects/forestregrowth/assets/projections/forest_2050_{scenario}")

    # get the area increase per 10km grid cell
    delta = scenario_2050.subtract(scenario_2015)

    scenario_growth = delta.updateMask(delta.gt(0).And(biomes)).rename(f'growth_{scenario}')

    scenarios_growth = scenarios_growth.addBands(scenario_growth)

scenarios_growth = scenarios_growth.slice(1).divide(10)
unified_data_scenarios = ee.Image.cat([scenarios_growth, unified_data])

grid_bezerra = ee.FeatureCollection("projects/forestregrowth/assets/grid_Bezerra_10_points")

unified_fc = unified_data_scenarios.reduceRegions(grid_bezerra, ee.Reducer.first(), 30)
properties_to_export = unified_data_scenarios.bandNames().getInfo()

task = ee.batch.Export.table.toDrive(
    collection = unified_fc,
    description = 'future_scenarios_area',
    fileFormat = "CSV",
    selectors = [p for p in properties_to_export if p not in ['system:index', '.geo']]
)
# task.start()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %% [markdown]
# ## Ecoregions
#
# Sample 10,000 points per ecoregion to estimate the lag per ecoregion

# %%
properties_to_export = unified_data_secondary.bandNames().getInfo()

# what if we stratify sample per age?

ecoreg_stratify = unified_data_secondary.stratifiedSample(numPoints=10000, classBand="ecoreg", region = amazon_geom)

task = ee.batch.Export.table.toDrive(
    collection = ecoreg_stratify,
    description = 'ecoreg_stratify',
    fileFormat = "CSV",
    selectors = [p for p in properties_to_export if p not in ['system:index', '.geo']]
)
# task.start()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
folder = 'projects/forestregrowth/assets/secondary_points'
assets = ee.data.listAssets({'parent': folder})['assets']

band_names = unified_data_secondary.bandNames().getInfo()

for asset in assets:
    fc = ee.FeatureCollection(asset['id'])

    sampled = unified_data_secondary.reduceRegions(
        collection=fc,
        reducer=ee.Reducer.first(),
        scale=30
    )

    task = ee.batch.Export.table.toDrive(
        collection=sampled,
        description=asset['id'][-3:],
        folder = 'all_points_amazon',
        fileFormat='CSV',
        selectors=band_names
    )
    # task.start()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
polygons = ee.FeatureCollection("projects/forestregrowth/assets/secondary_polygons/secondary_age_vectors_030")

grid = ee.FeatureCollection("projects/forestregrowth/assets/grid_10k_amazon_secondary_edge_removed")

map = geemap.Map()
map.centerObject(polygons, 10)
map.addLayer(polygons)
map.addLayer(grid)
map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[-12.907032513104827, -57.932191439915634], controls=(WidgetControl(options=['position', 'transpare…

# %%
map.addLayer(unified_data_secondary)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
